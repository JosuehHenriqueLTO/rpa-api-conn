# %%
import pandas as pd

tb=pd.read_csv("../rpa/data/products.csv", encoding="latin1")

display(tb.info())

# print(tb)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1000 non-null   str
#  1   product_type   1000 non-null   str
#  2   description    1000 non-null   str
#  3   monthly_sales  1000 non-null   int64
# dtypes: int64(1), str(3)
# memory usage: 31.4 KB
# None

# %%
tb = tb.dropna()
display(tb.describe().round(1))
# Out:
#        monthly_sales
# count         1000.0
# mean           255.2
# std            143.0
# min              5.0
# 25%            135.0
# 50%            253.0
# 75%            380.0
# max            500.0

# %%
import plotly.express as px

viewer = px.histogram(tb, x="monthly_sales")
viewer.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import plotly.express as px
#       3 viewer = px.histogram(tb, x="monthly_sales")
# ----> 4 viewer.show()
#
# File d:\GitHub\rpa-api-conn\backend\.venv\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File d:\GitHub\rpa-api-conn\backend\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
# ...
